# %%
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import QuantileTransformer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model import LassoLars
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import TweedieRegressor
import wrangle
import warnings
warnings.filterwarnings("ignore")
from sklearn.feature_selection import SelectKBest, RFE, f_regression, SequentialFeatureSelector
from pydataset import data
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re

# %%
df = pd.read_csv('final_df.csv',index_col=[0])
columns_list = df.select_dtypes(exclude=['object']).columns.to_list()

list_to_remove = ['conf_champ','avg_att_air_yards','avg_air_yard_diff','time_to_throw','air_yds_to_sticks','won_superbowl',
'avg_comp_air_yds','superbowl','year']

for i in list_to_remove:
    if i in columns_list:
        columns_list.remove(i)

        
target = columns_list.pop(len(columns_list) -1 )

# %%
X = df[columns_list]
y = df[target]

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    random_state=123)
parameters_lars = {
    'alpha':range(1,21),
    'fit_intercept':[True, False],
    'verbose': [True, False]
}

parameters_linear = {'n_jobs':range(1,21)
                }

parameters_glm = {
    'link':['auto', 'identity', 'log'],
    'alpha':range(1,21),
}

lars = LassoLars(random_state =123)
Linear_regression1 = LinearRegression()
glm = TweedieRegressor(power=2, alpha=0)


the_parameters = [parameters_lars, parameters_linear, parameters_glm]


models = ['lars','Linear_regression1','glm']
master_df = pd.DataFrame()
for number, tree in enumerate([lars, Linear_regression1, glm]):
    grid = GridSearchCV(tree, the_parameters[number], cv=5, scoring = 'neg_root_mean_squared_error')
    grid.fit(X_train, y_train)
    
    for p, score in zip(grid.cv_results_['params'], grid.cv_results_['mean_test_score']):
        p['score'] = abs(score)
        p['model'] = models[number]
    new_df = pd.DataFrame(pd.DataFrame(grid.cv_results_['params']).sort_values('score', ascending=True))
    master_df = pd.concat([master_df, new_df])

# %%
master_df
# Out:
#     alpha fit_intercept verbose     score               model  n_jobs  \
# 79   20.0         False   False  6.128393                lars     NaN
# 78   20.0         False    True  6.128393                lars     NaN
# 75   19.0         False   False  6.129814                lars     NaN
# 74   19.0         False    True  6.129814                lars     NaN
# 70   18.0         False    True  6.131291                lars     NaN
# 71   18.0         False   False  6.131291                lars     NaN
# 66   17.0         False    True  6.132822                lars     NaN
# 67   17.0         False   False  6.132822                lars     NaN
# 76   20.0          True    True  6.133877                lars     NaN
# 77   20.0          True   False  6.133877                lars     NaN
# 63   16.0         False   False  6.134408                lars     NaN
# 62   16.0         False    True  6.134408                lars     NaN
# ...

# %%
df = pd.read_csv('2022.csv',index_col=[0])

# %%
df['year'] = '2022'

# %%
df =df.drop(columns=['Pos'])

# %%
df
# Out:
#                    Player   Tm  Age   G  GS   QBrec  Cmp  Att   Cmp%   Yds  \
# Rk
# 1       Patrick Mahomes*+  KAN   27  17  17  14-3-0  435  648   67.1  5250
# 2          Justin Herbert  LAC   24  17  17  10-7-0  477  699   68.2  4739
# 3               Tom Brady  TAM   45  17  17   8-9-0  490  733   66.8  4694
# 4           Kirk Cousins*  MIN   34  17  17  13-4-0  424  643   65.9  4547
# 5             Joe Burrow*  CIN   26  16  16  12-4-0  414  606   68.3  4475
# 6             Jared Goff*  DET   28  17  17   9-8-0  382  587   65.1  4438
# 7             Josh Allen*  BUF   26  16  16  13-3-0  359  567   63.3  4283
# 8             Geno Smith*  SEA   32  17  17   9-8-0  399  572   69.8  4282
# 9        Trevor Lawrence*  JAX   23  17  17   9-8-0  387  584   66.3  4113
# 10           Jalen Hurts*  PHI   24  15  15  14-1-0  306  460   66.5  3701
# 11          Aaron Rodgers  GNB   39  17  17   8-9-0  350  542   64.6  3695
# ...

# %%
df1 = pd.read_csv('2022.csv',index_col=[0])
df1['year'] = '2022'
df1 =df1.drop(columns=['Pos'])
df1
# Out:
#                    Player   Tm  Age   G  GS   QBrec  Cmp  Att   Cmp%   Yds  \
# Rk
# 1       Patrick Mahomes*+  KAN   27  17  17  14-3-0  435  648   67.1  5250
# 2          Justin Herbert  LAC   24  17  17  10-7-0  477  699   68.2  4739
# 3               Tom Brady  TAM   45  17  17   8-9-0  490  733   66.8  4694
# 4           Kirk Cousins*  MIN   34  17  17  13-4-0  424  643   65.9  4547
# 5             Joe Burrow*  CIN   26  16  16  12-4-0  414  606   68.3  4475
# 6             Jared Goff*  DET   28  17  17   9-8-0  382  587   65.1  4438
# 7             Josh Allen*  BUF   26  16  16  13-3-0  359  567   63.3  4283
# 8             Geno Smith*  SEA   32  17  17   9-8-0  399  572   69.8  4282
# 9        Trevor Lawrence*  JAX   23  17  17   9-8-0  387  584   66.3  4113
# 10           Jalen Hurts*  PHI   24  15  15  14-1-0  306  460   66.5  3701
# 11          Aaron Rodgers  GNB   39  17  17   8-9-0  350  542   64.6  3695
# ...

# %%
df2 = pd.read_csv('2021.csv',index_col=[0])
df2['year'] = '2021'
df2 =df2.drop(columns=['Pos'])
df2
# Out:
#                     Player   Tm  Age   G  GS   QBrec  Cmp  Att   Cmp%   Yds  \
# Rk
# 1               Tom Brady*  TAM   44  17  17  13-4-0  485  719   67.5  5316
# 2          Justin Herbert*  LAC   23  17  17   9-8-0  443  672   65.9  5014
# 3         Matthew Stafford  LAR   33  17  17  12-5-0  404  601   67.2  4886
# 4         Patrick Mahomes*  KAN   26  17  17  12-5-0  436  658   66.3  4839
# 5               Derek Carr  LVR   30  17  17  10-7-0  428  626   68.4  4804
# 6               Joe Burrow  CIN   25  16  16  10-6-0  366  520   70.4  4611
# 7             Dak Prescott  DAL   28  16  16  11-5-0  410  596   68.8  4449
# 8               Josh Allen  BUF   25  17  17  11-6-0  409  646   63.3  4407
# 9            Kirk Cousins*  MIN   33  16  16   8-8-0  372  561   66.3  4221
# 10         Aaron Rodgers*+  GNB   38  16  16  13-3-0  366  531   68.9  4115
# 11               Matt Ryan  ATL   36  17  17  7-10-0  375  560   67.0  3968
# ...

# %%
df3 = pd.read_csv('2020.csv',index_col=[0])
df3['year'] = '2020'
df3 =df3.drop(columns=['Pos'])
df3
# Out:
#                  Player   Tm  Age   G  GS   QBrec  Cmp  Att   Cmp%   Yds  ...  \
# Rk                                                                        ...
# 1       Deshaun Watson*  HOU   25  16  16  4-12-0  382  544   70.2  4823  ...
# 2      Patrick Mahomes*  KAN   25  15  15  14-1-0  390  588   66.3  4740  ...
# 3             Tom Brady  TAM   43  16  16  11-5-0  401  610   65.7  4633  ...
# 4             Matt Ryan  ATL   35  16  16  4-12-0  407  626   65.0  4581  ...
# 5           Josh Allen*  BUF   24  16  16  13-3-0  396  572   69.2  4544  ...
# 6        Justin Herbert  LAC   22  15  15   6-9-0  396  595   66.6  4336  ...
# 7       Aaron Rodgers*+  GNB   37  16  16  13-3-0  372  526   70.7  4299  ...
# 8          Kirk Cousins  MIN   32  16  16   7-9-0  349  516   67.6  4265  ...
# 9       Russell Wilson*  SEA   32  16  16  12-4-0  384  558   68.8  4212  ...
# 10        Philip Rivers  IND   39  16  16  11-5-0  369  543   68.0  4169  ...
# ...

# %%
df4 = pd.read_csv('2019.csv',index_col=[0])
df4['year'] = '2019'
df4 =df4.drop(columns=['Pos'])
df4
# Out:
#                     Player   Tm  Age   G  GS   QBrec  Cmp  Att   Cmp%   Yds  \
# Rk
# 1           Jameis Winston  TAM   25  16  16   7-9-0  380  626   60.7  5109
# 2             Dak Prescott  DAL   26  16  16   8-8-0  388  596   65.1  4902
# 3               Jared Goff  LAR   25  16  16   9-7-0  394  626   62.9  4638
# 4            Philip Rivers  LAC   38  16  16  5-11-0  390  591   66.0  4615
# 5                Matt Ryan  ATL   34  15  15   7-8-0  408  616   66.2  4466
# 6          Russell Wilson*  SEA   31  16  16  11-5-0  341  516   66.1  4110
# 7                Tom Brady  NWE   42  16  16  12-4-0  373  613   60.8  4057
# 8               Derek Carr  OAK   28  16  16   7-9-0  361  513   70.4  4054
# 9             Carson Wentz  PHI   27  16  16   9-7-0  388  607   63.9  4039
# 10        Patrick Mahomes*  KAN   24  14  14  11-3-0  319  484   65.9  4031
# 11          Aaron Rodgers*  GNB   36  16  16  13-3-0  353  569   62.0  4002
# ...

# %%
df5 = pd.read_csv('2018.csv',index_col=[0])
df5['year'] = '2018'
df5 =df5.drop(columns=['Pos'])
df5
# Out:
#                   Player   Tm  Age   G  GS   QBrec  Cmp  Att   Cmp%   Yds  \
# Rk
# 1     Ben Roethlisberger  PIT   36  16  16   9-6-1  452  675   67.0  5129
# 2      Patrick Mahomes*+  KAN   23  16  16  12-4-0  383  580   66.0  5097
# 3              Matt Ryan  ATL   33  16  16   7-9-0  422  608   69.4  4924
# 4            Jared Goff*  LAR   24  16  16  13-3-0  364  561   64.9  4688
# 5           Andrew Luck*  IND   29  16  16  10-6-0  430  639   67.3  4593
# 6         Aaron Rodgers*  GNB   35  16  16   6-9-1  372  597   62.3  4442
# 7             Tom Brady*  NWE   41  16  16  11-5-0  375  570   65.8  4355
# 8         Philip Rivers*  LAC   37  16  16  12-4-0  347  508   68.3  4308
# 9            Eli Manning  NYG   37  16  16  5-11-0  380  576   66.0  4299
# 10          Kirk Cousins  MIN   30  16  16   8-7-1  425  606   70.1  4298
# 11       Deshaun Watson*  HOU   23  16  16  11-5-0  345  505   68.3  4165
# 12            Derek Carr  OAK   27  16  16  4-12-0  381  553   68.9  4049
# ...

# %%
df6 = pd.read_csv('2017.csv',index_col=[0])
df6['year'] = '2017'
df6 =df6.drop(columns=['Pos'])
df6
# Out:
#                  Player   Tm  Age   G  GS   QBrec  Cmp  Att   Cmp%   Yds  ...  \
# Rk                                                                        ...
# 1           Tom Brady*+  NWE   40  16  16  13-3-0  385  581   66.3  4577  ...
# 2        Philip Rivers*  LAC   36  16  16   9-7-0  360  575   62.6  4515  ...
# 3      Matthew Stafford  DET   29  16  16   9-7-0  371  565   65.7  4446  ...
# 4           Drew Brees*  NOR   38  16  16  11-5-0  386  536   72.0  4334  ...
# 5   Ben Roethlisberger*  PIT   35  15  15  12-3-0  360  561   64.2  4251  ...
# 6             Matt Ryan  ATL   32  16  16  10-6-0  342  529   64.7  4095  ...
# 7          Kirk Cousins  WAS   29  16  16   7-9-0  347  540   64.3  4093  ...
# 8           Alex Smith*  KAN   33  15  15   9-6-0  341  505   67.5  4042  ...
# 9       Russell Wilson*  SEA   29  16  16   9-7-0  339  553   61.3  3983  ...
# 10          Jared Goff*  LAR   23  15  15  11-4-0  296  477   62.1  3804  ...
# ...

# %%
df7 = pd.read_csv('2016.csv',index_col=[0])
df7['year'] = '2016'
df7 =df7.drop(columns=['Pos'])
df7
# Out:
#                  Player   Tm  Age   G  GS   QBrec  Cmp  Att   Cmp%   Yds  ...  \
# Rk                                                                        ...
# 1           Drew Brees*  NOR   37  16  16   7-9-0  471  673   70.0  5208  ...
# 2           Matt Ryan*+  ATL   31  16  16  11-5-0  373  534   69.9  4944  ...
# 3         Kirk Cousins*  WAS   28  16  16   8-7-1  406  606   67.0  4917  ...
# 4        Aaron Rodgers*  GNB   33  16  16  10-6-0  401  610   65.7  4428  ...
# 5        Philip Rivers*  SDG   35  16  16  5-11-0  349  578   60.4  4386  ...
# 6      Matthew Stafford  DET   28  16  16   9-7-0  388  594   65.3  4327  ...
# 7            Joe Flacco  BAL   31  16  16   8-8-0  436  672   64.9  4317  ...
# 8           Andrew Luck  IND   27  15  15   8-7-0  346  545   63.5  4240  ...
# 9         Carson Palmer  ARI   37  15  15   6-8-1  364  597   61.0  4233  ...
# 10       Russell Wilson  SEA   28  16  16  10-5-1  353  546   64.7  4219  ...
# ...

# %%
df8 = pd.read_csv('2015.csv',index_col=[0])
df8['year'] = '2015'
df8 =df8.drop(columns=['Pos'])
df8
# Out:
#                  Player   Tm  Age   G  GS   QBrec  Cmp  Att   Cmp%   Yds  ...  \
# Rk                                                                        ...
# 1            Drew Brees  NOR   36  15  15   7-8-0  428  627   68.3  4870  ...
# 2         Philip Rivers  SDG   34  16  16  4-12-0  437  661   66.1  4792  ...
# 3            Tom Brady*  NWE   38  16  16  12-4-0  402  624   64.4  4770  ...
# 4        Carson Palmer*  ARI   36  16  16  13-3-0  342  537   63.7  4671  ...
# 5             Matt Ryan  ATL   30  16  16   8-8-0  407  614   66.3  4591  ...
# 6          Eli Manning*  NYG   34  16  16  6-10-0  387  618   62.6  4432  ...
# 7         Blake Bortles  JAX   23  16  16  5-11-0  355  606   58.6  4428  ...
# 8      Matthew Stafford  DET   27  16  16   7-9-0  398  592   67.2  4262  ...
# 9        Ryan Tannehill  MIA   27  16  16  6-10-0  363  586   61.9  4208  ...
# 10         Kirk Cousins  WAS   27  16  16   9-7-0  379  543   69.8  4166  ...
# ...

# %%
df9 = pd.read_csv('2014.csv',index_col=[0])
df9['year'] = '2014'
df9 =df9.drop(columns=['Pos'])
df9
# Out:
#                   Player   Tm  Age   G  GS   QBrec  Cmp  Att   Cmp%   Yds  \
# Rk
# 1            Drew Brees*  NOR   35  16  16   7-9-0  456  659   69.2  4952
# 2    Ben Roethlisberger*  PIT   32  16  16  11-5-0  408  608   67.1  4952
# 3           Andrew Luck*  IND   25  16  16  11-5-0  380  616   61.7  4761
# 4        Peyton Manning*  DEN   38  16  16  12-4-0  395  597   66.2  4727
# 5             Matt Ryan*  ATL   29  16  16  6-10-0  415  628   66.1  4694
# 6            Eli Manning  NYG   33  16  16  6-10-0  379  601   63.1  4410
# 7        Aaron Rodgers*+  GNB   31  16  16  12-4-0  341  520   65.6  4381
# 8          Philip Rivers  SDG   33  16  16   9-7-0  379  570   66.5  4286
# 9      Matthew Stafford*  DET   26  16  16  11-5-0  363  602   60.3  4257
# 10            Tom Brady*  NWE   37  16  16  12-4-0  373  582   64.1  4109
# 11        Ryan Tannehill  MIA   26  16  16   8-8-0  392  590   66.4  4045
# 12            Joe Flacco  BAL   29  16  16  10-6-0  344  554   62.1  3986
# ...

# %%
df10 = pd.read_csv('2013.csv',index_col=[0])
df10['year'] = '2013'
df10 =df10.drop(columns=['Pos'])
df10
# Out:
#                 Player   Tm  Age   G  GS   QBrec  Cmp  Att   Cmp%   Yds  ...  \
# Rk                                                                       ...
# 1     Peyton Manning*+  DEN   37  16  16  13-3-0  450  659   68.3  5477  ...
# 2          Drew Brees*  NOR   34  16  16  11-5-0  446  650   68.6  5162  ...
# 3     Matthew Stafford  DET   25  16  16   7-9-0  371  634   58.5  4650  ...
# 4            Matt Ryan  ATL   28  16  16  4-12-0  439  651   67.4  4515  ...
# 5       Philip Rivers*  SDG   32  16  16   9-7-0  378  544   69.5  4478  ...
# 6           Tom Brady*  NWE   36  16  16  12-4-0  380  628   60.5  4343  ...
# 7          Andy Dalton  CIN   26  16  16  11-5-0  363  586   61.9  4293  ...
# 8        Carson Palmer  ARI   34  16  16  10-6-0  362  572   63.3  4274  ...
# 9   Ben Roethlisberger  PIT   31  16  16   8-8-0  375  584   64.2  4261  ...
# 10      Ryan Tannehill  MIA   25  16  16   8-8-0  355  588   60.4  3913  ...
# ...

# %%
df11 = pd.read_csv('2012.csv',index_col=[0])
df11['year'] = '2012'
df11 =df11.drop(columns=['Pos'])
df11
# Out:
#                  Player   Tm  Age   G  GS   QBrec  Cmp  Att   Cmp%   Yds  ...  \
# Rk                                                                        ...
# 1           Drew Brees*  NOR   33  16  16   7-9-0  422  670   63.0  5177  ...
# 2      Matthew Stafford  DET   24  16  16  4-12-0  435  727   59.8  4967  ...
# 3             Tony Romo  DAL   32  16  16   8-8-0  425  648   65.6  4903  ...
# 4            Tom Brady*  NWE   35  16  16  12-4-0  401  637   63.0  4827  ...
# 5            Matt Ryan*  ATL   27  16  16  13-3-0  422  615   68.6  4719  ...
# 6      Peyton Manning*+  DEN   36  16  16  13-3-0  400  583   68.6  4659  ...
# 7          Andrew Luck*  IND   23  16  16  11-5-0  339  627   54.1  4374  ...
# 8        Aaron Rodgers*  GNB   29  16  16  11-5-0  371  552   67.2  4295  ...
# 9          Josh Freeman  TAM   24  16  16   7-9-0  306  558   54.8  4065  ...
# 10        Carson Palmer  OAK   33  15  15  4-11-0  345  565   61.1  4018  ...
# ...

# %%
df12 = pd.read_csv('2011.csv',index_col=[0])
df12['year'] = '2011'
df12 =df12.drop(columns=['Pos'])
df12
# Out:
#                  Player   Tm  Age   G  GS   QBrec  Cmp  Att   Cmp%   Yds  ...  \
# Rk                                                                        ...
# 1           Drew Brees*  NOR   32  16  16  13-3-0  468  657   71.2  5476  ...
# 2            Tom Brady*  NWE   34  16  16  13-3-0  401  611   65.6  5235  ...
# 3      Matthew Stafford  DET   23  16  16  10-6-0  421  663   63.5  5038  ...
# 4          Eli Manning*  NYG   30  16  16   9-7-0  359  589   61.0  4933  ...
# 5       Aaron Rodgers*+  GNB   28  15  15  14-1-0  343  502   68.3  4643  ...
# 6        Philip Rivers*  SDG   30  16  16   8-8-0  366  582   62.9  4624  ...
# 7             Tony Romo  DAL   31  16  16   8-8-0  346  522   66.3  4184  ...
# 8             Matt Ryan  ATL   26  16  16  10-6-0  347  566   61.3  4177  ...
# 9   Ben Roethlisberger*  PIT   29  15  15  11-4-0  324  513   63.2  4077  ...
# 10          Cam Newton*  CAR   22  16  16  6-10-0  310  517   60.0  4051  ...
# ...

# %%
df13 = pd.read_csv('2010.csv',index_col=[0])
df13['year'] = '2010'
df13 =df13.drop(columns=['Pos'])
df13
# Out:
#                   Player   Tm  Age   G  GS   QBrec  Cmp  Att   Cmp%   Yds  \
# Rk
# 1         Philip Rivers*  SDG   29  16  16   9-7-0  357  541   66.0  4710
# 2        Peyton Manning*  IND   34  16  16  10-6-0  450  679   66.3  4700
# 3            Drew Brees*  NOR   31  16  16  11-5-0  448  658   68.1  4620
# 4            Matt Schaub  HOU   29  16  16  6-10-0  365  574   63.6  4370
# 5            Eli Manning  NYG   29  16  16  10-6-0  339  539   62.9  4002
# 6          Carson Palmer  CIN   31  16  16  4-12-0  362  586   61.8  3970
# 7          Aaron Rodgers  GNB   27  15  15  10-5-0  312  475   65.7  3922
# 8            Tom Brady*+  NWE   33  16  16  14-2-0  324  492   65.9  3900
# 9             Matt Ryan*  ATL   25  16  16  13-3-0  357  571   62.5  3705
# 10            Kyle Orton  DEN   28  13  13  3-10-0  293  498   58.8  3653
# 11            Joe Flacco  BAL   25  16  16  12-4-0  306  489   62.6  3622
# 12          Sam Bradford  STL   23  16  16   7-9-0  354  590   60.0  3512
# ...

# %%
master_df_new_data = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11, df12,df13])

# %%
master_df_new_data = master_df_new_data.rename(columns={'TD%': 'td_perc', 'Int%': 'int_perc', '1D':'fir_dn_throws', 'Lng':'lng_comp', 'Y/C':'yds_per_cat', 'Y/G':'yds_per_gm'})

# %%
master_df_new_data = master_df_new_data.rename(columns ={'yds_per_cat':'yds_per_comp'})

# %%
def clean_name(name):
    cleaned_name = re.sub(r'[^\w\s]+$', '', name)
    return cleaned_name

# %%
# test_df['year2'] = np.where(test_df.year.isnull(), test_df['3_y'], test_df.year )

# %%
master_df_new_data.QBrec = np.where(master_df_new_data.QBrec.isnull(), '0-0', master_df_new_data.QBrec)

# %%
master_df_new_data
# Out:
#                Player   Tm  Age   G  GS   QBrec  Cmp  Att   Cmp%   Yds  ...  \
# Rk                                                                      ...
# 1     Patrick Mahomes  KAN   27  17  17  14-3-0  435  648   67.1  5250  ...
# 2      Justin Herbert  LAC   24  17  17  10-7-0  477  699   68.2  4739  ...
# 3           Tom Brady  TAM   45  17  17   8-9-0  490  733   66.8  4694  ...
# 4        Kirk Cousins  MIN   34  17  17  13-4-0  424  643   65.9  4547  ...
# 5          Joe Burrow  CIN   26  16  16  12-4-0  414  606   68.3  4475  ...
# ..                ...  ...  ...  ..  ..     ...  ...  ...    ...   ...  ...
# 98       Stefan Logan  DET   29  16   0     0-0    0    1    0.0     0  ...
# 99   Brandon Marshall  MIA   26  14  14     0-0    0    1    0.0     0  ...
# 100   Darren McFadden  OAK   23  13  13     0-0    0    1    0.0     0  ...
# 101  Micheal Spurlock  TAM   27  16   1     0-0    0    3    0.0     0  ...
# ...

# %%
master_df_new_data['Player'] = master_df_new_data['Player'].apply(clean_name)

# %%
df = pd.read_csv('pivot_final.csv',index_col=[0])

# %%
master_df_new_data = master_df_new_data.assign(win=master_df_new_data['QBrec'].str.split('-').str[0].astype(int),
                   loss=master_df_new_data['QBrec'].str.split('-').str[1].astype(int))

# %%
master_df_new_data.head()
# Out:
#              Player   Tm  Age   G  GS   QBrec  Cmp  Att  Cmp%   Yds  ...  \
# Rk                                                                   ...
# 1   Patrick Mahomes  KAN   27  17  17  14-3-0  435  648  67.1  5250  ...
# 2    Justin Herbert  LAC   24  17  17  10-7-0  477  699  68.2  4739  ...
# 3         Tom Brady  TAM   45  17  17   8-9-0  490  733  66.8  4694  ...
# 4      Kirk Cousins  MIN   34  17  17  13-4-0  424  643  65.9  4547  ...
# 5        Joe Burrow  CIN   26  16  16  12-4-0  414  606  68.3  4475  ...
#
#     Yds.1  Sk%  NY/A  ANY/A  4QC  GWD  Player-additional  year  win  loss
# Rk
# 1     188  3.9  7.51   7.93  4.0  4.0           MahoPa00  2022   14     3
# 2     206  5.2  6.15   6.22  4.0  5.0           HerbJu00  2022   10     7
# 3     160  2.9  6.01   6.13  4.0  5.0           BradTo00  2022    8     9
# 4     329  6.7  6.12   6.05  8.0  8.0           CousKi00  2022   13     4
# 5     259  6.3  6.52   6.76  3.0  4.0           BurrJo01  2022   12     4
#
# ...

# %%
df =df.reset_index()

# %%
df.shape
# Out:
# (458, 19)

# %%
df.head()
# Out:
#              name team  year  games_played   comp    att  comp_pct     yds  \
# 0    Rex Grossman  WAS  2010           4.0   74.0  133.0      55.6   884.0
# 1    Rex Grossman  WAS  2011          13.0  265.0  458.0      57.9  3148.0
# 2      Matt Flynn   GB  2013           7.0  124.0  200.0      62.0  1392.0
# 3      Matt Flynn   GB  2013           7.0  124.0  200.0      62.0  1392.0
# 4  Jameis Winston   TB  2015          16.0  312.0  535.0      58.3  4042.0
#
#    avg_yds_per_att    td   int  pass_rating  rush_att  rush_yds  rush_avg  \
# 0              6.6   7.0   4.0        81.16       3.0       6.0       2.0
# 1              6.9  16.0  20.0        72.39      20.0      11.0       0.6
# 2              7.0   8.0   5.0        85.67      20.0      65.0       3.2
# 3              7.0   8.0   5.0        85.67      20.0      65.0       3.2
# 4              7.6  22.0  15.0        84.19      54.0     213.0       3.9
#
#    rush_td       full_name  year_signed  percent_of_cap
# ...

# %%
master_df_new_data.year = master_df_new_data.year.astype('int')

# %%
master_df_new_data.year.value_counts(dropna= False)
# Out:
# 2021    115
# 2020    112
# 2022    106
# 2018    106
# 2019    102
# 2010    102
# 2014    100
# 2016     96
# 2011     96
# 2017     94
# 2015     86
# 2013     85
# 2012     85
# Name: year, dtype: int64

# %%
pd.set_option('display.max_columns', None)

# %%
master_df_new_data[['Age', 'td_perc', 'int_perc', 'fir_dn_throws', 'lng_comp', 'yds_per_comp', 'yds_per_gm', 'QBR', 'Sk', '4QC', 'GWD', 'win', 'loss','year']][master_df_new_data['Player'] == 'Ben Roethlisberger'].sort_values(by='year')
# Out:
#     Age  td_perc  int_perc  fir_dn_throws  lng_comp  yds_per_comp  yds_per_gm  \
# Rk
# 18   28      4.4       1.3            149        56          13.3       266.7
# 9    29      4.1       2.7            210        95          12.6       271.8
# 21   30      5.8       1.8            167        82          11.5       251.2
# 9    31      4.8       2.4            211        67          11.4       266.3
# 2    32      5.3       1.5            244        94          12.1       309.5
# 14   33      4.5       3.4            175        69          12.3       328.2
# 17   34      5.7       2.6            184        72          11.6       272.8
# 5    35      5.0       2.5            204        97          11.8       283.4
# 1    36      5.0       2.4            248        97          11.3       320.6
# 52   37      0.0       1.6             14        45          10.0       175.5
# 16   38      5.4       1.6            193        84           9.5       253.5
# ...

# %%
df = df.merge(master_df_new_data[['Player','year','Age', 'td_perc', 'int_perc', 'fir_dn_throws', 'lng_comp', 'yds_per_comp', 'yds_per_gm', 'QBR', 'Sk', '4QC', 'GWD', 'win', 'loss']], 
                   left_on =['name', 'year'], 
                   right_on = ['Player', 'year'], how = 'inner')

# %%
df['QBR'] = df['QBR'].fillna(df['QBR'].mean())

# %%
df['QBR'].mean()
# Out:
# 52.59757709251101

# %%
df['4QC'] = df['4QC'].fillna(0)

# %%
df['GWD'] = df['GWD'].fillna(0)

# %%
df.isnull().sum()
# Out:
# name               0
# team               0
# year               0
# games_played       0
# comp               0
# att                0
# comp_pct           0
# yds                0
# avg_yds_per_att    0
# td                 0
# int                0
# pass_rating        0
# rush_att           0
# rush_yds           0
# rush_avg           0
# rush_td            0
# full_name          0
# year_signed        0
# percent_of_cap     0
# Player             0
# Age                0
# td_perc            0
# int_perc           0
# fir_dn_throws      0
# lng_comp           0
# yds_per_comp       0
# yds_per_gm         0
# QBR                0
# Sk                 0
# 4QC                0
# GWD                0
# win                0
# loss               0
# dtype: int64

# %%
df['4QC'].mean()
# Out:
# 1.4649122807017543

# %%
df.to_csv('pivot_final_2.csv', index=False)
